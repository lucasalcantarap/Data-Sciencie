# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasalcantarap/Data-Sciencie/blob/master/DS_do_zero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Visualização de dados, objetivos: Visualizar dados e comunicar dados

import matplotlib as plt
from matplotlib import pyplot as plt

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

#cria um gráfico de linha, anos non eixo x, gdp no eixo y

plt.plot(years,gdp,color ='green', marker = 'o',linestyle = 'solid')

#adiciona um titulo
plt.title('GDP Nominal')

#adiciona selo nos eixos
plt.ylabel('Bilhões de $')
plt.show()

# %%
#Um gráfico de barra é uma boa escolha quando você quer mostrar como algumas
#quantidades variam entre um conjunto particular de itens.

filmes = ["Annie Hall", "Ben-Hur", "CasaBlanca","Gandhi", "West Side Story"]
num_oscars = [5,11,3,8,10]

# barras possuem o tamanho padrão de 0.8, então adicionaremos 0.1 às
# coordenadas à esquerda para que cada barra seja centralizada

xs = [i + 0.1 for i,_ in enumerate(filmes)]

# as barras do gráfico com as coordenadas x à esquerda [xs], alturas [num_oscars]
plt.bar(xs,num_oscars)

plt.ylabel('# de Premiações')
plt.title('Meus Filmes Favoritos')

# nomeia o eixo x com nomes de filmes na barra central
plt.xticks([i + 0.5 for i, _ in enumerate(filmes)],filmes)
#plt.xticks([i + 0.5 for i, _ in enumerate(filmes)], filmes)

plt.show()
